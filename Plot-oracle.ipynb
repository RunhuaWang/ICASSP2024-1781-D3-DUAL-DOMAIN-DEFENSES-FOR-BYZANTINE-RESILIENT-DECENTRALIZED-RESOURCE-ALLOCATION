# %% [markdown]
# # 数据导入

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import random
from sympy import *
import math 
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
#数据导入
#DGD+无攻击 oracle
agent_resource_quantity_oracle = np.loadtxt("./data/agent_resource_quantity_oracle.txt")
average_cost_oracle=np.loadtxt("./data/average_cost_oracle.txt")
average_resource_oracle=np.loadtxt("./data/average_resource_oracle.txt")
dual_variable_oracle=np.loadtxt("./data/dual_variable_oracle.txt")
#DGD+极小值攻击
agent_resource_quantity_min_attack=np.loadtxt("./data/00_DGD_agent_resource_quantity_min_attack.txt")
average_cost_honest_min_attack=np.loadtxt("./data/00_DGD_average_cost_honest_min_attack.txt")
average_resource_honest_min_attack=np.loadtxt("./data/00_DGD_average_resource_honest_min_attack.txt")
dual_variable_min_attack=np.loadtxt("./data/00_DGD_dual_variable_min_attack.txt")
#DGD+极大值攻击
agent_resource_quantity_max_attack=np.loadtxt("./data/00_DGD_agent_resource_quantity_max_attack.txt")
average_cost_honest_max_attack=np.loadtxt("./data/00_DGD_average_cost_honest_max_attack.txt")
average_resource_honest_max_attack=np.loadtxt("./data/00_DGD_average_resource_honest_max_attack.txt")
dual_variable_max_attack=np.loadtxt("./data/00_DGD_dual_variable_max_attack.txt")
#DGD+高斯攻击——大值
agent_resource_quantity_Gaussian_attack_large=np.loadtxt("./data/00_DGD_agent_resource_quantity_Gaussian_attack_large.txt")
average_cost_honest_Gaussian_attack_large=np.loadtxt("./data/00_DGD_average_cost_honest_Gaussian_attack_large.txt")
average_resource_honest_Gaussian_attack_large=np.loadtxt("./data/00_DGD_average_resource_honest_Gaussian_attack_large.txt")
dual_variable_Gaussian_attack_large=np.loadtxt("./data/00_DGD_dual_variable_Gaussian_attack_large.txt")
#DGD+高斯攻击——小值
agent_resource_quantity_Gaussian_attack_small=np.loadtxt("./data/00_DGD_agent_resource_quantity_Gaussian_attack_small.txt")
average_cost_honest_Gaussian_attack_small=np.loadtxt("./data/00_DGD_average_cost_honest_Gaussian_attack_small.txt")
average_resource_honest_Gaussian_attack_small=np.loadtxt("./data/00_DGD_average_resource_honest_Gaussian_attack_small.txt")
dual_variable_Gaussian_attack_small=np.loadtxt("./data/00_DGD_dual_variable_Gaussian_attack_small.txt")

#IOS
#极小值攻击
agent_resource_quantity_min_attack_IOS=np.loadtxt("./data/01_IOS_oracle_agent_resource_quantity_min_attack.txt")
average_cost_honest_min_attack_IOS=np.loadtxt("./data/01_IOS_oracle_average_cost_honest_min_attack.txt")
average_resource_honest_min_attack_IOS=np.loadtxt("./data/01_IOS_oracle_average_resource_honest_min_attack.txt")
dual_variable_min_attack_IOS=np.loadtxt("./data/01_IOS_oracle_dual_variable_min_attack.txt")
#极大值攻击
agent_resource_quantity_max_attack_IOS=np.loadtxt("./data/01_IOS_oracle_agent_resource_quantity_max_attack.txt")
average_cost_honest_max_attack_IOS=np.loadtxt("./data/01_IOS_oracle_average_cost_honest_max_attack.txt")
average_resource_honest_max_attack_IOS=np.loadtxt("./data/01_IOS_oracle_average_resource_honest_max_attack.txt")
dual_variable_max_attack_IOS=np.loadtxt("./data/01_IOS_oracle_dual_variable_max_attack.txt")
#高斯攻击——大值
agent_resource_quantity_Gaussian_attack_large_IOS=np.loadtxt("./data/01_IOS_oracle_agent_resource_quantity_Gaussian_attack_large.txt")
average_cost_honest_Gaussian_attack_large_IOS=np.loadtxt("./data/01_IOS_oracle_average_cost_honest_Gaussian_attack_large.txt")
average_resource_honest_Gaussian_attack_large_IOS=np.loadtxt("./data/01_IOS_oracle_average_resource_honest_Gaussian_attack_large.txt")
dual_variable_Gaussian_attack_large_IOS=np.loadtxt("./data/01_IOS_oracle_dual_variable_Gaussian_attack_large.txt")
#高斯攻击——小值
agent_resource_quantity_Gaussian_attack_small_IOS=np.loadtxt("./data/01_IOS_oracle_agent_resource_quantity_Gaussian_attack_small.txt")
average_cost_honest_Gaussian_attack_small_IOS=np.loadtxt("./data/01_IOS_oracle_average_cost_honest_Gaussian_attack_small.txt")
average_resource_honest_Gaussian_attack_small_IOS=np.loadtxt("./data/01_IOS_oracle_average_resource_honest_Gaussian_attack_small.txt")
dual_variable_Gaussian_attack_small_IOS=np.loadtxt("./data/01_IOS_oracle_dual_variable_Gaussian_attack_small.txt")

#TM
#极小值攻击
agent_resource_quantity_min_attack_TM=np.loadtxt("./data/02_TM_oracle_agent_resource_quantity_min_attack.txt")
average_cost_honest_min_attack_TM=np.loadtxt("./data/02_TM_oracle_average_cost_honest_min_attack.txt")
average_resource_honest_min_attack_TM=np.loadtxt("./data/02_TM_oracle_average_resource_honest_min_attack.txt")
dual_variable_min_attack_TM=np.loadtxt("./data/02_TM_oracle_dual_variable_min_attack.txt")
#极大值攻击
agent_resource_quantity_max_attack_TM=np.loadtxt("./data/02_TM_oracle_agent_resource_quantity_max_attack.txt")
average_cost_honest_max_attack_TM=np.loadtxt("./data/02_TM_oracle_average_cost_honest_max_attack.txt")
average_resource_honest_max_attack_TM=np.loadtxt("./data/02_TM_oracle_average_resource_honest_max_attack.txt")
dual_variable_max_attack_TM=np.loadtxt("./data/02_TM_oracle_dual_variable_max_attack.txt")
#高斯攻击——大值
agent_resource_quantity_Gaussian_attack_large_TM=np.loadtxt("./data/02_TM_oracle_agent_resource_quantity_Gaussian_attack_large.txt")
average_cost_honest_Gaussian_attack_large_TM=np.loadtxt("./data/02_TM_oracle_average_cost_honest_Gaussian_attack_large.txt")
average_resource_honest_Gaussian_attack_large_TM=np.loadtxt("./data/02_TM_oracle_average_resource_honest_Gaussian_attack_large.txt")
dual_variable_Gaussian_attack_large_TM=np.loadtxt("./data/02_TM_oracle_dual_variable_Gaussian_attack_large.txt")
#高斯攻击——小值
agent_resource_quantity_Gaussian_attack_small_TM=np.loadtxt("./data/02_TM_oracle_agent_resource_quantity_Gaussian_attack_small.txt")
average_cost_honest_Gaussian_attack_small_TM=np.loadtxt("./data/02_TM_oracle_average_cost_honest_Gaussian_attack_small.txt")
average_resource_honest_Gaussian_attack_small_TM=np.loadtxt("./data/02_TM_oracle_average_resource_honest_Gaussian_attack_small.txt")
dual_variable_Gaussian_attack_small_TM=np.loadtxt("./data/02_TM_oracle_dual_variable_Gaussian_attack_small.txt")

#SCC
#极小值攻击
agent_resource_quantity_min_attack_SCC=np.loadtxt("./data/03_SCC_oracle_agent_resource_quantity_min_attack.txt")
average_cost_honest_min_attack_SCC=np.loadtxt("./data/03_SCC_oracle_average_cost_honest_min_attack.txt")
average_resource_honest_min_attack_SCC=np.loadtxt("./data/03_SCC_oracle_average_resource_honest_min_attack.txt")
dual_variable_min_attack_SCC=np.loadtxt("./data/03_SCC_oracle_dual_variable_min_attack.txt")
#极大值攻击
agent_resource_quantity_max_attack_SCC=np.loadtxt("./data/03_SCC_oracle_agent_resource_quantity_max_attack.txt")
average_cost_honest_max_attack_SCC=np.loadtxt("./data/03_SCC_oracle_average_cost_honest_max_attack.txt")
average_resource_honest_max_attack_SCC=np.loadtxt("./data/03_SCC_oracle_average_resource_honest_max_attack.txt")
dual_variable_max_attack_SCC=np.loadtxt("./data/03_SCC_oracle_dual_variable_max_attack.txt")
#高斯攻击——大值
agent_resource_quantity_Gaussian_attack_large_SCC=np.loadtxt("./data/03_SCC_oracle_agent_resource_quantity_Gaussian_attack_large.txt")
average_cost_honest_Gaussian_attack_large_SCC=np.loadtxt("./data/03_SCC_oracle_average_cost_honest_Gaussian_attack_large.txt")
average_resource_honest_Gaussian_attack_large_SCC=np.loadtxt("./data/03_SCC_oracle_average_resource_honest_Gaussian_attack_large.txt")
dual_variable_Gaussian_attack_large_SCC=np.loadtxt("./data/03_SCC_oracle_dual_variable_Gaussian_attack_large.txt")
#高斯攻击——小值
agent_resource_quantity_Gaussian_attack_small_SCC=np.loadtxt("./data/03_SCC_oracle_agent_resource_quantity_Gaussian_attack_small.txt")
average_cost_honest_Gaussian_attack_small_SCC=np.loadtxt("./data/03_SCC_oracle_average_cost_honest_Gaussian_attack_small.txt")
average_resource_honest_Gaussian_attack_small_SCC=np.loadtxt("./data/03_SCC_oracle_average_resource_honest_Gaussian_attack_small.txt")
dual_variable_Gaussian_attack_small_SCC=np.loadtxt("./data/03_SCC_oracle_dual_variable_Gaussian_attack_small.txt")

#BREDA
#极小值攻击
agent_resource_quantity_min_attack_BREDA=np.loadtxt("./data/BREDA_TM_oracle_agent_resource_quantity_min_attack.txt")
average_cost_honest_min_attack_BREDA=np.loadtxt("./data/BREDA_TM_oracle_average_cost_honest_min_attack.txt")
average_resource_honest_min_attack_BREDA=np.loadtxt("./data/BREDA_TM_oracle_average_resource_honest_min_attack.txt")
dual_variable_min_attack_BREDA=np.loadtxt("./data/BREDA_TM_oracle_dual_variable_min_attack.txt")
#极大值攻击
agent_resource_quantity_max_attack_BREDA=np.loadtxt("./data/BREDA_TM_oracle_agent_resource_quantity_max_attack.txt")
average_cost_honest_max_attack_BREDA=np.loadtxt("./data/BREDA_TM_oracle_average_cost_honest_max_attack.txt")
average_resource_honest_max_attack_BREDA=np.loadtxt("./data/BREDA_TM_oracle_average_resource_honest_max_attack.txt")
dual_variable_max_attack_BREDA=np.loadtxt("./data/BREDA_TM_oracle_dual_variable_max_attack.txt")

# %% [markdown]
# # 相关数据计算

# %% [raw]
# 小值攻击

# %%
#数据计算 所有诚实用户资源量和无攻击情况下最优资源量的gap——小值攻击
#计算所有诚实用户资源量和无攻击情况下最优资源量的gap——小值攻击
#DGD
sum1_DGD_small=[]
sum1_DGD_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_min_attack[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_min_attack[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_DGD_small.append(sqrt(sum))
for i in range(0,len(sum1_DGD_small)):
    sum1_DGD_small_log2.append(math.log(sum1_DGD_small[i],2))       
#IOS
sum1_IOS_small=[]
sum1_IOS_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_min_attack_IOS[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_min_attack_IOS[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_IOS_small.append(sqrt(sum))
for i in range(0,len(sum1_IOS_small)):
    sum1_IOS_small_log2.append(math.log(sum1_IOS_small[i],2))
#TM
sum1_TM_small=[]
sum1_TM_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_min_attack_TM[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_min_attack_TM[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_TM_small.append(sqrt(sum))
for i in range(0,len(sum1_TM_small)):
    sum1_TM_small_log2.append(math.log(sum1_TM_small[i],2))   
#SCC
sum1_SCC_small=[]
sum1_SCC_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_min_attack_SCC[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_min_attack_SCC[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_SCC_small.append(sqrt(sum))
for i in range(0,len(sum1_SCC_small)):
    sum1_SCC_small_log2.append(math.log(sum1_SCC_small[i],2))
#BREDA
sum1_BREDA_small=[]
sum1_BREDA_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_min_attack_BREDA[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_min_attack_BREDA[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_BREDA_small.append(sqrt(sum))
for i in range(0,len(sum1_BREDA_small)):
    sum1_BREDA_small_log2.append(math.log(sum1_BREDA_small[i],2))
##################################################################################################################
#数据计算 所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
#对偶变量的最优性误差 所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap——小值攻击
#DGD
sum2_DGD_small=[]
sum2_DGD_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack[i][k]-dual_variable_oracle[i][59999])
    sum2_DGD_small.append(sum)
for i in range(0,len(sum2_DGD_small)):
    sum2_DGD_small_log2.append(math.log(sum2_DGD_small[i],2)) 
#IOS
sum2_IOS_small=[]
sum2_IOS_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack_IOS[i][k]-dual_variable_oracle[i][59999])
    sum2_IOS_small.append(sum)
for i in range(0,len(sum2_IOS_small)):
    sum2_IOS_small_log2.append(math.log(sum2_IOS_small[i],2))
#TM
sum2_TM_small=[]
sum2_TM_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack_TM[i][k]-dual_variable_oracle[i][59999])
    sum2_TM_small.append(sum)
for i in range(0,len(sum2_TM_small)):
    sum2_TM_small_log2.append(math.log(sum2_TM_small[i],2))
#SCC
sum2_SCC_small=[]
sum2_SCC_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack_SCC[i][k]-dual_variable_oracle[i][59999])
    sum2_SCC_small.append(sum)
for i in range(0,len(sum2_SCC_small)):
    sum2_SCC_small_log2.append(math.log(sum2_SCC_small[i],2))
#BREDA
sum2_BREDA_small=[]
sum2_BREDA_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack_BREDA[i][k]-dual_variable_oracle[i][59999])
    sum2_BREDA_small.append(sum)
for i in range(0,len(sum2_BREDA_small)):
    sum2_BREDA_small_log2.append(math.log(sum2_BREDA_small[i],2))
##################################################################################################################
#数据计算 诚实用户平均成本和无攻击情况下平均成本的gap
#诚实用户平均成本和无攻击情况下平均成本的gap——小值攻击
#DGD
cost_gap_DGD_small=[]
for k in range(0,59999):
    cost_gap_DGD_small.append(abs(average_cost_honest_min_attack[k]-average_cost_oracle[59999]))   
cost_gap_DGD_small_log2=[]
for i in range(0,len(cost_gap_DGD_small)):
    cost_gap_DGD_small_log2.append(math.log(cost_gap_DGD_small[i],2))       
#IOS
cost_gap_IOS_small=[]
for k in range(0,59999):
    cost_gap_IOS_small.append(abs(average_cost_honest_min_attack_IOS[k]-average_cost_oracle[59999]))
cost_gap_IOS_small_log2=[]
for i in range(0,len(cost_gap_IOS_small)):
    cost_gap_IOS_small_log2.append(math.log(cost_gap_IOS_small[i],2)) 
#TM
cost_gap_TM_small=[]
for k in range(0,59999):
    cost_gap_TM_small.append(abs(average_cost_honest_min_attack_TM[k]-average_cost_oracle[59999]))
cost_gap_TM_small_log2=[]
for i in range(0,len(cost_gap_TM_small)):
    cost_gap_TM_small_log2.append(math.log(cost_gap_TM_small[i],2)) 
#SCC
cost_gap_SCC_small=[]
for k in range(0,59999):
    cost_gap_SCC_small.append(abs(average_cost_honest_min_attack_SCC[k]-average_cost_oracle[59999]))
cost_gap_SCC_small_log2=[]
for i in range(0,len(cost_gap_SCC_small)):
    cost_gap_SCC_small_log2.append(math.log(cost_gap_SCC_small[i],2))
#BREDA
cost_gap_BREDA_small=[]
for k in range(0,59999):
    cost_gap_BREDA_small.append(abs(average_cost_honest_min_attack_BREDA[k]-average_cost_oracle[59999]))
cost_gap_BREDA_small_log2=[]
for i in range(0,len(cost_gap_BREDA_small)):
    cost_gap_BREDA_small_log2.append(math.log(cost_gap_BREDA_small[i],2))
#######################################################################################################################
#数据计算 平均资源约束违反程度 诚实用户平均资源量和平均资源约束间的gap
#平均资源约束违反程度 诚实用户平均资源量和平均资源约束间的gap——小值攻击
#DGD
average_resource_gap_DGD_small=[]
for k in range(0,59999):
    average_resource_gap_DGD_small.append(abs(average_resource_honest_min_attack[k]-50))
average_resource_gap_DGD_small_log2=[]
for i in range(0,len(average_resource_gap_DGD_small)):
    average_resource_gap_DGD_small_log2.append(math.log(average_resource_gap_DGD_small[i],2))     
#IOS
average_resource_gap_IOS_small=[]
for k in range(0,59999):
    average_resource_gap_IOS_small.append(abs(average_resource_honest_min_attack_IOS[k]-50))
average_resource_gap_IOS_small_log2=[]
for i in range(0,len(average_resource_gap_IOS_small)):
    average_resource_gap_IOS_small_log2.append(math.log(average_resource_gap_IOS_small[i],2)) 
#TM
average_resource_gap_TM_small=[]
for k in range(0,59999):
    average_resource_gap_TM_small.append(abs(average_resource_honest_min_attack_TM[k]-50))
average_resource_gap_TM_small_log2=[]
for i in range(0,len(average_resource_gap_TM_small)):
    average_resource_gap_TM_small_log2.append(math.log(average_resource_gap_TM_small[i],2))
#SCC
average_resource_gap_SCC_small=[]
for k in range(0,59999):
    average_resource_gap_SCC_small.append(abs(average_resource_honest_min_attack_SCC[k]-50))
average_resource_gap_SCC_small_log2=[]
for i in range(0,len(average_resource_gap_SCC_small)):
    average_resource_gap_SCC_small_log2.append(math.log(average_resource_gap_SCC_small[i],2))
#BREDA
average_resource_gap_BREDA_small=[]
for k in range(0,59999):
    average_resource_gap_BREDA_small.append(abs(average_resource_honest_min_attack_BREDA[k]-50))
average_resource_gap_BREDA_small_log2=[]
for i in range(0,len(average_resource_gap_BREDA_small)):
    average_resource_gap_BREDA_small_log2.append(math.log(average_resource_gap_BREDA_small[i],2))

# %% [raw]
# 大值攻击

# %%
#数据计算 所有诚实用户资源量和无攻击情况下最优资源量的gap——大值攻击
#计算所有诚实用户资源量和无攻击情况下最优资源量的gap——大值攻击
#DGD
sum1_DGD_large=[]
sum1_DGD_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_max_attack[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_max_attack[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_DGD_large.append(sqrt(sum))
for i in range(0,len(sum1_DGD_large)):
    sum1_DGD_large_log2.append(math.log(sum1_DGD_large[i],2))       
#IOS
sum1_IOS_large=[]
sum1_IOS_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_max_attack_IOS[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_max_attack_IOS[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_IOS_large.append(sqrt(sum))
for i in range(0,len(sum1_IOS_large)):
    sum1_IOS_large_log2.append(math.log(sum1_IOS_large[i],2))
#TM
sum1_TM_large=[]
sum1_TM_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_max_attack_TM[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_max_attack_TM[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_TM_large.append(sqrt(sum))
for i in range(0,len(sum1_TM_large)):
    sum1_TM_large_log2.append(math.log(sum1_TM_large[i],2))   
#SCC
sum1_SCC_large=[]
sum1_SCC_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_max_attack_SCC[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_max_attack_SCC[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_SCC_large.append(sqrt(sum))
for i in range(0,len(sum1_SCC_large)):
    sum1_SCC_large_log2.append(math.log(sum1_SCC_large[i],2))
#BREDA
sum1_BREDA_large=[]
sum1_BREDA_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_max_attack_BREDA[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_max_attack_BREDA[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_BREDA_large.append(sqrt(sum))
for i in range(0,len(sum1_BREDA_large)):
    sum1_BREDA_large_log2.append(math.log(sum1_BREDA_large[i],2))
##################################################################################################################
#数据计算 所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
#对偶变量的最优性误差 所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap——大值攻击
#DGD
sum2_DGD_large=[]
sum2_DGD_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack[i][k]-dual_variable_oracle[i][59999])
    sum2_DGD_large.append(sum)
for i in range(0,len(sum2_DGD_large)):
    sum2_DGD_large_log2.append(math.log(sum2_DGD_large[i],2)) 
#IOS
sum2_IOS_large=[]
sum2_IOS_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack_IOS[i][k]-dual_variable_oracle[i][59999])
    sum2_IOS_large.append(sum)
for i in range(0,len(sum2_IOS_large)):
    sum2_IOS_large_log2.append(math.log(sum2_IOS_large[i],2))
#TM
sum2_TM_large=[]
sum2_TM_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack_TM[i][k]-dual_variable_oracle[i][59999])
    sum2_TM_large.append(sum)
for i in range(0,len(sum2_TM_large)):
    sum2_TM_large_log2.append(math.log(sum2_TM_large[i],2))
#SCC
sum2_SCC_large=[]
sum2_SCC_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack_SCC[i][k]-dual_variable_oracle[i][59999])
    sum2_SCC_large.append(sum)
for i in range(0,len(sum2_SCC_large)):
    sum2_SCC_large_log2.append(math.log(sum2_SCC_large[i],2))
#BREDA
sum2_BREDA_large=[]
sum2_BREDA_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack_BREDA[i][k]-dual_variable_oracle[i][59999])
    sum2_BREDA_large.append(sum)
for i in range(0,len(sum2_BREDA_large)):
    sum2_BREDA_large_log2.append(math.log(sum2_BREDA_large[i],2))
##################################################################################################################
#数据计算 诚实用户平均成本和无攻击情况下平均成本的gap
#诚实用户平均成本和无攻击情况下平均成本的gap—大值攻击
#DGD
cost_gap_DGD_large=[]
for k in range(0,59999):
    cost_gap_DGD_large.append(abs(average_cost_honest_max_attack[k]-average_cost_oracle[59999]))   
cost_gap_DGD_large_log2=[]
for i in range(0,len(cost_gap_DGD_large)):
    cost_gap_DGD_large_log2.append(math.log(cost_gap_DGD_large[i],2))       
#IOS
cost_gap_IOS_large=[]
for k in range(0,59999):
    cost_gap_IOS_large.append(abs(average_cost_honest_max_attack_IOS[k]-average_cost_oracle[59999]))
cost_gap_IOS_large_log2=[]
for i in range(0,len(cost_gap_IOS_large)):
    cost_gap_IOS_large_log2.append(math.log(cost_gap_IOS_large[i],2)) 
#TM
cost_gap_TM_large=[]
for k in range(0,59999):
    cost_gap_TM_large.append(abs(average_cost_honest_max_attack_TM[k]-average_cost_oracle[59999]))
cost_gap_TM_large_log2=[]
for i in range(0,len(cost_gap_TM_large)):
    cost_gap_TM_large_log2.append(math.log(cost_gap_TM_large[i],2)) 
#SCC
cost_gap_SCC_large=[]
for k in range(0,59999):
    cost_gap_SCC_large.append(abs(average_cost_honest_max_attack_SCC[k]-average_cost_oracle[59999]))
cost_gap_SCC_large_log2=[]
for i in range(0,len(cost_gap_SCC_large)):
    cost_gap_SCC_large_log2.append(math.log(cost_gap_SCC_large[i],2))
#BREDA
cost_gap_BREDA_large=[]
for k in range(0,59999):
    cost_gap_BREDA_large.append(abs(average_cost_honest_max_attack_BREDA[k]-average_cost_oracle[59999]))
cost_gap_BREDA_large_log2=[]
for i in range(0,len(cost_gap_BREDA_large)):
    cost_gap_BREDA_large_log2.append(math.log(cost_gap_BREDA_large[i],2))
#######################################################################################################################
#数据计算 平均资源约束违反程度 诚实用户平均资源量和平均资源约束间的gap
#平均资源约束违反程度 诚实用户平均资源量和平均资源约束间的gap—大值攻击
#DGD
average_resource_gap_DGD_large=[]
for k in range(0,59999):
    average_resource_gap_DGD_large.append(abs(average_resource_honest_max_attack[k]-50))
average_resource_gap_DGD_large_log2=[]
for i in range(0,len(average_resource_gap_DGD_large)):
    average_resource_gap_DGD_large_log2.append(math.log(average_resource_gap_DGD_large[i],2))     
#IOS
average_resource_gap_IOS_large=[]
for k in range(0,59999):
    average_resource_gap_IOS_large.append(abs(average_resource_honest_max_attack_IOS[k]-50))
average_resource_gap_IOS_large_log2=[]
for i in range(0,len(average_resource_gap_IOS_large)):
    average_resource_gap_IOS_large_log2.append(math.log(average_resource_gap_IOS_large[i],2)) 
#TM
average_resource_gap_TM_large=[]
for k in range(0,59999):
    average_resource_gap_TM_large.append(abs(average_resource_honest_max_attack_TM[k]-50))
average_resource_gap_TM_large_log2=[]
for i in range(0,len(average_resource_gap_TM_large)):
    average_resource_gap_TM_large_log2.append(math.log(average_resource_gap_TM_large[i],2))
#SCC
average_resource_gap_SCC_large=[]
for k in range(0,59999):
    average_resource_gap_SCC_large.append(abs(average_resource_honest_max_attack_SCC[k]-50))
average_resource_gap_SCC_large_log2=[]
for i in range(0,len(average_resource_gap_SCC_large)):
    average_resource_gap_SCC_large_log2.append(math.log(average_resource_gap_SCC_large[i],2))
#BREDA
average_resource_gap_BREDA_large=[]
for k in range(0,59999):
    average_resource_gap_BREDA_large.append(abs(average_resource_honest_max_attack_BREDA[k]-50))
average_resource_gap_BREDA_large_log2=[]
for i in range(0,len(average_resource_gap_BREDA_large)):
    average_resource_gap_BREDA_large_log2.append(math.log(average_resource_gap_BREDA_large[i],2))

# %% [raw]
# 高斯攻击——大值

# %%
#数据计算 所有诚实用户资源量和无攻击情况下最优资源量的gap——高斯大值攻击
#计算所有诚实用户资源量和无攻击情况下最优资源量的gap——高斯大值攻击
#DGD
sum1_DGD_Gaussian_large=[]
sum1_DGD_Gaussian_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_Gaussian_attack_large[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_Gaussian_attack_large[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_DGD_Gaussian_large.append(sqrt(sum))
for i in range(0,len(sum1_DGD_Gaussian_large)):
    sum1_DGD_Gaussian_large_log2.append(math.log(sum1_DGD_Gaussian_large[i],2))       
#IOS
sum1_IOS_Gaussian_large=[]
sum1_IOS_Gaussian_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_Gaussian_attack_large_IOS[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_Gaussian_attack_large_IOS[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_IOS_Gaussian_large.append(sqrt(sum))
for i in range(0,len(sum1_IOS_Gaussian_large)):
    sum1_IOS_Gaussian_large_log2.append(math.log(sum1_IOS_Gaussian_large[i],2))
#TM
sum1_TM_Gaussian_large=[]
sum1_TM_Gaussian_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_Gaussian_attack_large_TM[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_Gaussian_attack_large_TM[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_TM_Gaussian_large.append(sqrt(sum))
for i in range(0,len(sum1_TM_Gaussian_large)):
    sum1_TM_Gaussian_large_log2.append(math.log(sum1_TM_Gaussian_large[i],2))   
#SCC
sum1_SCC_Gaussian_large=[]
sum1_SCC_Gaussian_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_Gaussian_attack_large_SCC[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_Gaussian_attack_large_SCC[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_SCC_Gaussian_large.append(sqrt(sum))
for i in range(0,len(sum1_SCC_Gaussian_large)):
    sum1_SCC_Gaussian_large_log2.append(math.log(sum1_SCC_Gaussian_large[i],2))
##################################################################################################################
#数据计算 所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
#对偶变量的最优性误差 所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap——高斯大值攻击
#DGD
sum2_DGD_Gaussian_large=[]
sum2_DGD_Gaussian_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_large[i][k]-dual_variable_oracle[i][59999])
    sum2_DGD_Gaussian_large.append(sum)
for i in range(0,len(sum2_DGD_Gaussian_large)):
    sum2_DGD_Gaussian_large_log2.append(math.log(sum2_DGD_Gaussian_large[i],2)) 
#IOS
sum2_IOS_Gaussian_large=[]
sum2_IOS_Gaussian_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_large_IOS[i][k]-dual_variable_oracle[i][59999])
    sum2_IOS_Gaussian_large.append(sum)
for i in range(0,len(sum2_IOS_Gaussian_large)):
    sum2_IOS_Gaussian_large_log2.append(math.log(sum2_IOS_Gaussian_large[i],2))
#TM
sum2_TM_Gaussian_large=[]
sum2_TM_Gaussian_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_large_TM[i][k]-dual_variable_oracle[i][59999])
    sum2_TM_Gaussian_large.append(sum)
for i in range(0,len(sum2_TM_Gaussian_large)):
    sum2_TM_Gaussian_large_log2.append(math.log(sum2_TM_Gaussian_large[i],2))
#SCC
sum2_SCC_Gaussian_large=[]
sum2_SCC_Gaussian_large_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_large_SCC[i][k]-dual_variable_oracle[i][59999])
    sum2_SCC_Gaussian_large.append(sum)
for i in range(0,len(sum2_SCC_Gaussian_large)):
    sum2_SCC_Gaussian_large_log2.append(math.log(sum2_SCC_Gaussian_large[i],2))
##################################################################################################################
#数据计算 诚实用户平均成本和无攻击情况下平均成本的gap
#诚实用户平均成本和无攻击情况下平均成本的gap—高斯大值攻击
#DGD
cost_gap_DGD_Gaussian_large=[]
for k in range(0,59999):
    cost_gap_DGD_Gaussian_large.append(abs(average_cost_honest_Gaussian_attack_large[k]-average_cost_oracle[59999]))   
cost_gap_DGD_Gaussian_large_log2=[]
for i in range(0,len(cost_gap_DGD_Gaussian_large)):
    cost_gap_DGD_Gaussian_large_log2.append(math.log(cost_gap_DGD_Gaussian_large[i],2))       
#IOS
cost_gap_IOS_Gaussian_large=[]
for k in range(0,59999):
    cost_gap_IOS_Gaussian_large.append(abs(average_cost_honest_Gaussian_attack_large_IOS[k]-average_cost_oracle[59999]))
cost_gap_IOS_Gaussian_large_log2=[]
for i in range(0,len(cost_gap_IOS_Gaussian_large)):
    cost_gap_IOS_Gaussian_large_log2.append(math.log(cost_gap_IOS_Gaussian_large[i],2)) 
#TM
cost_gap_TM_Gaussian_large=[]
for k in range(0,59999):
    cost_gap_TM_Gaussian_large.append(abs(average_cost_honest_Gaussian_attack_large_TM[k]-average_cost_oracle[59999]))
cost_gap_TM_Gaussian_large_log2=[]
for i in range(0,len(cost_gap_TM_Gaussian_large)):
    cost_gap_TM_Gaussian_large_log2.append(math.log(cost_gap_TM_Gaussian_large[i],2)) 
#SCC
cost_gap_SCC_Gaussian_large=[]
for k in range(0,59999):
    cost_gap_SCC_Gaussian_large.append(abs(average_cost_honest_Gaussian_attack_large_SCC[k]-average_cost_oracle[59999]))
cost_gap_SCC_Gaussian_large_log2=[]
for i in range(0,len(cost_gap_SCC_Gaussian_large)):
    cost_gap_SCC_Gaussian_large_log2.append(math.log(cost_gap_SCC_Gaussian_large[i],2))
#######################################################################################################################
#数据计算 平均资源约束违反程度 诚实用户平均资源量和平均资源约束间的gap
#平均资源约束违反程度 诚实用户平均资源量和平均资源约束间的gap—高斯大值攻击
#DGD
average_resource_gap_DGD_Gaussian_large=[]
for k in range(0,59999):
    average_resource_gap_DGD_Gaussian_large.append(abs(average_resource_honest_Gaussian_attack_large[k]-50))
average_resource_gap_DGD_Gaussian_large_log2=[]
for i in range(0,len(average_resource_gap_DGD_Gaussian_large)):
    average_resource_gap_DGD_Gaussian_large_log2.append(math.log(average_resource_gap_DGD_Gaussian_large[i],2))     
#IOS
average_resource_gap_IOS_Gaussian_large=[]
for k in range(0,59999):
    average_resource_gap_IOS_Gaussian_large.append(abs(average_resource_honest_Gaussian_attack_large_IOS[k]-50))
average_resource_gap_IOS_Gaussian_large_log2=[]
for i in range(0,len(average_resource_gap_IOS_Gaussian_large)):
    average_resource_gap_IOS_Gaussian_large_log2.append(math.log(average_resource_gap_IOS_Gaussian_large[i],2)) 
#TM
average_resource_gap_TM_Gaussian_large=[]
for k in range(0,59999):
    average_resource_gap_TM_Gaussian_large.append(abs(average_resource_honest_Gaussian_attack_large_TM[k]-50))
average_resource_gap_TM_Gaussian_large_log2=[]
for i in range(0,len(average_resource_gap_TM_Gaussian_large)):
    average_resource_gap_TM_Gaussian_large_log2.append(math.log(average_resource_gap_TM_Gaussian_large[i],2))
#SCC
average_resource_gap_SCC_Gaussian_large=[]
for k in range(0,59999):
    average_resource_gap_SCC_Gaussian_large.append(abs(average_resource_honest_Gaussian_attack_large_SCC[k]-50))
average_resource_gap_SCC_Gaussian_large_log2=[]
for i in range(0,len(average_resource_gap_SCC_Gaussian_large)):
    average_resource_gap_SCC_Gaussian_large_log2.append(math.log(average_resource_gap_SCC_Gaussian_large[i],2))

# %% [raw]
# 高斯攻击——小值

# %%
#数据计算 所有诚实用户资源量和无攻击情况下最优资源量的gap——高斯小值攻击
#计算所有诚实用户资源量和无攻击情况下最优资源量的gap——高斯小值攻击
#DGD
sum1_DGD_Gaussian_small=[]
sum1_DGD_Gaussian_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_Gaussian_attack_small[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_Gaussian_attack_small[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_DGD_Gaussian_small.append(sqrt(sum))
for i in range(0,len(sum1_DGD_Gaussian_small)):
    sum1_DGD_Gaussian_small_log2.append(math.log(sum1_DGD_Gaussian_small[i],2))       
#IOS
sum1_IOS_Gaussian_small=[]
sum1_IOS_Gaussian_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_Gaussian_attack_small_IOS[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_Gaussian_attack_small_IOS[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_IOS_Gaussian_small.append(sqrt(sum))
for i in range(0,len(sum1_IOS_Gaussian_small)):
    sum1_IOS_Gaussian_small_log2.append(math.log(sum1_IOS_Gaussian_small[i],2))
#TM
sum1_TM_Gaussian_small=[]
sum1_TM_Gaussian_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_Gaussian_attack_small_TM[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_Gaussian_attack_small_TM[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_TM_Gaussian_small.append(sqrt(sum))
for i in range(0,len(sum1_TM_Gaussian_small)):
    sum1_TM_Gaussian_small_log2.append(math.log(sum1_TM_Gaussian_small[i],2))   
#SCC
sum1_SCC_Gaussian_small=[]
sum1_SCC_Gaussian_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+(abs(agent_resource_quantity_Gaussian_attack_small_SCC[i][k]-agent_resource_quantity_oracle[i][59999])*abs(agent_resource_quantity_Gaussian_attack_small_SCC[i][k]-agent_resource_quantity_oracle[i][59999]))
    sum1_SCC_Gaussian_small.append(sqrt(sum))
for i in range(0,len(sum1_SCC_Gaussian_small)):
    sum1_SCC_Gaussian_small_log2.append(math.log(sum1_SCC_Gaussian_small[i],2))
##################################################################################################################
#数据计算 所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
#对偶变量的最优性误差 所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap——高斯小值攻击
#DGD
sum2_DGD_Gaussian_small=[]
sum2_DGD_Gaussian_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_small[i][k]-dual_variable_oracle[i][59999])
    sum2_DGD_Gaussian_small.append(sum)
for i in range(0,len(sum2_DGD_Gaussian_small)):
    sum2_DGD_Gaussian_small_log2.append(math.log(sum2_DGD_Gaussian_small[i],2)) 
#IOS
sum2_IOS_Gaussian_small=[]
sum2_IOS_Gaussian_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_small_IOS[i][k]-dual_variable_oracle[i][59999])
    sum2_IOS_Gaussian_small.append(sum)
for i in range(0,len(sum2_IOS_Gaussian_small)):
    sum2_IOS_Gaussian_small_log2.append(math.log(sum2_IOS_Gaussian_small[i],2))
#TM
sum2_TM_Gaussian_small=[]
sum2_TM_Gaussian_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_small_TM[i][k]-dual_variable_oracle[i][59999])
    sum2_TM_Gaussian_small.append(sum)
for i in range(0,len(sum2_TM_Gaussian_small)):
    sum2_TM_Gaussian_small_log2.append(math.log(sum2_TM_Gaussian_small[i],2))
#SCC
sum2_SCC_Gaussian_small=[]
sum2_SCC_Gaussian_small_log2=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_small_SCC[i][k]-dual_variable_oracle[i][59999])
    sum2_SCC_Gaussian_small.append(sum)
for i in range(0,len(sum2_SCC_Gaussian_small)):
    sum2_SCC_Gaussian_small_log2.append(math.log(sum2_SCC_Gaussian_small[i],2))
##################################################################################################################
#数据计算 诚实用户平均成本和无攻击情况下平均成本的gap
#诚实用户平均成本和无攻击情况下平均成本的gap—高斯小值攻击
#DGD
cost_gap_DGD_Gaussian_small=[]
for k in range(0,59999):
    cost_gap_DGD_Gaussian_small.append(abs(average_cost_honest_Gaussian_attack_small[k]-average_cost_oracle[59999]))   
cost_gap_DGD_Gaussian_small_log2=[]
for i in range(0,len(cost_gap_DGD_Gaussian_small)):
    cost_gap_DGD_Gaussian_small_log2.append(math.log(cost_gap_DGD_Gaussian_small[i],2))       
#IOS
cost_gap_IOS_Gaussian_small=[]
for k in range(0,59999):
    cost_gap_IOS_Gaussian_small.append(abs(average_cost_honest_Gaussian_attack_small_IOS[k]-average_cost_oracle[59999]))
cost_gap_IOS_Gaussian_small_log2=[]
for i in range(0,len(cost_gap_IOS_Gaussian_small)):
    cost_gap_IOS_Gaussian_small_log2.append(math.log(cost_gap_IOS_Gaussian_small[i],2)) 
#TM
cost_gap_TM_Gaussian_small=[]
for k in range(0,59999):
    cost_gap_TM_Gaussian_small.append(abs(average_cost_honest_Gaussian_attack_small_TM[k]-average_cost_oracle[59999]))
cost_gap_TM_Gaussian_small_log2=[]
for i in range(0,len(cost_gap_TM_Gaussian_small)):
    cost_gap_TM_Gaussian_small_log2.append(math.log(cost_gap_TM_Gaussian_small[i],2)) 
#SCC
cost_gap_SCC_Gaussian_small=[]
for k in range(0,59999):
    cost_gap_SCC_Gaussian_small.append(abs(average_cost_honest_Gaussian_attack_small_SCC[k]-average_cost_oracle[59999]))
cost_gap_SCC_Gaussian_small_log2=[]
for i in range(0,len(cost_gap_SCC_Gaussian_small)):
    cost_gap_SCC_Gaussian_small_log2.append(math.log(cost_gap_SCC_Gaussian_small[i],2))
#######################################################################################################################
#数据计算 平均资源约束违反程度 诚实用户平均资源量和平均资源约束间的gap
#平均资源约束违反程度 诚实用户平均资源量和平均资源约束间的gap—高斯小值攻击
#DGD
average_resource_gap_DGD_Gaussian_small=[]
for k in range(0,59999):
    average_resource_gap_DGD_Gaussian_small.append(abs(average_resource_honest_Gaussian_attack_small[k]-50))
average_resource_gap_DGD_Gaussian_small_log2=[]
for i in range(0,len(average_resource_gap_DGD_Gaussian_small)):
    average_resource_gap_DGD_Gaussian_small_log2.append(math.log(average_resource_gap_DGD_Gaussian_small[i],2))     
#IOS
average_resource_gap_IOS_Gaussian_small=[]
for k in range(0,59999):
    average_resource_gap_IOS_Gaussian_small.append(abs(average_resource_honest_Gaussian_attack_small_IOS[k]-50))
average_resource_gap_IOS_Gaussian_small_log2=[]
for i in range(0,len(average_resource_gap_IOS_Gaussian_small)):
    average_resource_gap_IOS_Gaussian_small_log2.append(math.log(average_resource_gap_IOS_Gaussian_small[i],2)) 
#TM
average_resource_gap_TM_Gaussian_small=[]
for k in range(0,59999):
    average_resource_gap_TM_Gaussian_small.append(abs(average_resource_honest_Gaussian_attack_small_TM[k]-50))
average_resource_gap_TM_Gaussian_small_log2=[]
for i in range(0,len(average_resource_gap_TM_Gaussian_small)):
    average_resource_gap_TM_Gaussian_small_log2.append(math.log(average_resource_gap_TM_Gaussian_small[i],2))
#SCC
average_resource_gap_SCC_Gaussian_small=[]
for k in range(0,59999):
    average_resource_gap_SCC_Gaussian_small.append(abs(average_resource_honest_Gaussian_attack_small_SCC[k]-50))
average_resource_gap_SCC_Gaussian_small_log2=[]
for i in range(0,len(average_resource_gap_SCC_Gaussian_small)):
    average_resource_gap_SCC_Gaussian_small_log2.append(math.log(average_resource_gap_SCC_Gaussian_small[i],2))

# %% [markdown]
# # 新绘图排版

# %% [markdown]
# # 已2为底的结果

# %%
sub1=plt.subplot(2, 4, 1)##############################################################
#大值攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum1_DGD_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum1_IOS_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum1_TM_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum1_SCC_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],sum1_BREDA_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

#plt.xlabel('Number of iterations',font)
plt.ylabel('primal optimality',font)
plt.title('large-value',font) 
#plt.ylim(-7,10)

plt.yticks([-2,0,2,4,6,8], [r'$2^{-2}$', r'$2^{0}$', r'$2^{2}$', r'$2^{4}$', r'$2^{6}$', r'$2^{8}$'])


sub2=plt.subplot(2, 4, 2)##############################################################
#小值攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum1_DGD_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum1_IOS_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='prposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum1_TM_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum1_SCC_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],sum1_BREDA_small_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.ylim(0,10)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
plt.title('small-value',font)
#plt.ylim(0.1,9.5)

sub3=plt.subplot(2, 4, 3)##############################################################
#大值高斯攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum1_DGD_Gaussian_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum1_IOS_Gaussian_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum1_TM_Gaussian_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum1_SCC_Gaussian_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
plt.title('large-value Gaussian',font)
#plt.ylim(0.1,9.5)


sub4=plt.subplot(2, 4, 4)##############################################################
#小值高斯攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum1_DGD_Gaussian_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum1_IOS_Gaussian_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum1_TM_Gaussian_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum1_SCC_Gaussian_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
plt.title('small-value Gaussian',font)
#plt.ylim(0.1,9.5)


sub5=plt.subplot(2, 4, 5)##############################################################
#大值攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum2_DGD_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum2_IOS_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum2_TM_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum2_SCC_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],sum2_BREDA_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

plt.xlabel('number of iterations',font)
plt.ylabel('dual optimality',font)
#plt.title('Large value attacks',font)
#plt.ylim(2.4,7.9)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub5.set_xticks(x_ticks)'''

plt.yticks([2,4,6,8,10,12,14], [r'$2^{2}$', r'$2^{4}$',r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$', r'$2^{14}$'])

sub6=plt.subplot(2, 4, 6)##############################################################
#小值攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum2_DGD_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum2_IOS_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum2_TM_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum2_SCC_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],sum2_BREDA_small_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Small value attacks',font)
#plt.ylim(2.4,7.9)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub6.set_xticks(x_ticks)'''

#plt.yticks([6, 8, 10, 12], [r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$'])

sub7=plt.subplot(2, 4, 7)##############################################################
#大值高斯攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum2_DGD_Gaussian_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum2_IOS_Gaussian_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum2_TM_Gaussian_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum2_SCC_Gaussian_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Trimmed large value Gaussian attacks',font)
#plt.ylim(2.4,7.9)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub7.set_xticks(x_ticks)'''

#plt.yticks([6, 8, 10, 12], [r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$'])

sub8=plt.subplot(2, 4, 8)##############################################################
#小值高斯攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum2_DGD_Gaussian_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum2_IOS_Gaussian_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum2_TM_Gaussian_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum2_SCC_Gaussian_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Trimmed small value Gaussian attacks',font)
#plt.ylim(2.4,7.9)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub8.set_xticks(x_ticks)'''

#plt.yticks([6, 8, 10, 12], [r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$'])

plt.legend(handles=[A, C, B, D, E],prop={'size':39},loc="upper center", bbox_to_anchor=[-1.06, -0.2],
           ncol=18, shadow=True, fancybox=True)
sub1.set_xticklabels([])
sub2.set_xticklabels([])
sub3.set_xticklabels([])
sub4.set_xticklabels([])

sub2.set_yticklabels([])
sub3.set_yticklabels([])
sub4.set_yticklabels([])
sub6.set_yticklabels([])
sub7.set_yticklabels([])
sub8.set_yticklabels([])

plt.subplots_adjust(wspace=0.03,hspace=0.05) 
plt.gcf().set_size_inches((38, 16))

plt.savefig('./figures/figure1_primal_dual_oracle_log2_four_attacks.pdf',format='pdf', bbox_inches='tight')
plt.savefig('./figures/figure1_primal_dual_oracle_log2_four_attacks.png',format='png', bbox_inches='tight')
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # 以2为底的结果

# %%
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter
sub1=plt.subplot(2, 4, 1)##############################################################
#大值攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_DGD_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_IOS_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_TM_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_SCC_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_BREDA_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

#plt.xlabel('Number of iterations',font)
plt.ylabel('cost optimality',font)
plt.title('large-value',font)  
#plt.ylim(3,14)

plt.yticks([2, 4, 6, 8, 10, 12], [r'$2^{2}$',r'$2^{4}$', r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$'])

sub2=plt.subplot(2, 4, 2)##############################################################
#小值攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_DGD_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_IOS_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_TM_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_SCC_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_BREDA_small_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.ylim(3,14)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
plt.title('small-value',font)
#plt.ylim(0,12000)


sub3=plt.subplot(2, 4, 3)##############################################################
#大值高斯攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_DGD_Gaussian_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_IOS_Gaussian_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_TM_Gaussian_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_SCC_Gaussian_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.ylim(3,14)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
plt.title('large-value Gaussian',font, x=0.57,y=1)

sub4=plt.subplot(2, 4, 4)##############################################################
#小值高斯攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_DGD_Gaussian_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_IOS_Gaussian_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_TM_Gaussian_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_SCC_Gaussian_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)
#plt.ylim(3,14)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
plt.title('small-value Gaussian ',font, x=0.57,y=1)
#plt.ylim(0,20000)
#plt.ylim(0,12000)

sub5=plt.subplot(2, 4, 5)##############################################################
#大值攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_DGD_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_IOS_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_TM_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_SCC_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_BREDA_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

plt.xlabel('number of iterations',font)
plt.ylabel('constraint violation',font)
#plt.title('Large value attacks',font)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub5.set_xticks(x_ticks)'''

plt.yticks([-6, -4, -2, 0, 2, 4, 6], [r'$2^{-6}$', r'$2^{-4}$', r'$2^{-2}$', r'$2^{0}$', r'$2^{2}$', r'$2^{4}$', r'$2^{6}$'])

sub6=plt.subplot(2, 4, 6)##############################################################
#小值攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_DGD_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_IOS_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_TM_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_SCC_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_BREDA_small_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Small value attacks',font)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub6.set_xticks(x_ticks)'''

sub7=plt.subplot(2, 4, 7)##############################################################
#大值高斯攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_DGD_Gaussian_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_IOS_Gaussian_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_TM_Gaussian_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_SCC_Gaussian_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Trimmed large value Gaussian attacks',font)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub7.set_xticks(x_ticks)'''

sub8=plt.subplot(2, 4, 8)##############################################################
#小值高斯攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_DGD_Gaussian_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_IOS_Gaussian_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_TM_Gaussian_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_SCC_Gaussian_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 46,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=30)

plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Trimmed small value Gaussian attacks',font)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub8.set_xticks(x_ticks)'''

plt.legend(handles=[A, C, B, D, E],prop={'size':39},loc="upper center", bbox_to_anchor=[-1.06, -0.2],
           ncol=18, shadow=True, fancybox=True)
sub1.set_xticklabels([])
sub2.set_xticklabels([])
sub3.set_xticklabels([])
sub4.set_xticklabels([])

sub2.set_yticklabels([])
sub3.set_yticklabels([])
sub4.set_yticklabels([])
sub6.set_yticklabels([])
sub7.set_yticklabels([])
sub8.set_yticklabels([])

plt.subplots_adjust(wspace=0.03,hspace=0.05) 
plt.gcf().set_size_inches((38, 16))
#plt.savefig('./figures/figure2_cost_constraint_oracle_log2_four_attacks.pdf',format='pdf', bbox_inches='tight')
#plt.savefig('./figures/figure2_cost_constraint_oracle_log2_four_attacks.png',format='png', bbox_inches='tight')

# %%
sub1=plt.subplot(4, 4, 1)##############################################################
#大值攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum1_DGD_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum1_IOS_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum1_TM_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum1_SCC_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],sum1_BREDA_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

#plt.xlabel('Number of iterations',font)
plt.ylabel('primal optimality',font)
plt.title('large-value',font) 
#plt.ylim(-7,10)

plt.yticks([-2,0,2,4,6,8], [r'$2^{-2}$', r'$2^{0}$', r'$2^{2}$', r'$2^{4}$', r'$2^{6}$', r'$2^{8}$'])


sub2=plt.subplot(4, 4, 2)##############################################################
#小值攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum1_DGD_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum1_IOS_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='prposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum1_TM_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum1_SCC_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],sum1_BREDA_small_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)
#plt.ylim(0,10)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
plt.title('small-value',font)
#plt.ylim(0.1,9.5)

sub3=plt.subplot(4, 4, 3)##############################################################
#大值高斯攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum1_DGD_Gaussian_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum1_IOS_Gaussian_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum1_TM_Gaussian_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum1_SCC_Gaussian_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
plt.title('large-value Gaussian',font)
#plt.ylim(0.1,9.5)


sub4=plt.subplot(4, 4, 4)##############################################################
#小值高斯攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum1_DGD_Gaussian_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum1_IOS_Gaussian_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum1_TM_Gaussian_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum1_SCC_Gaussian_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
plt.title('small-value Gaussian',font)
#plt.ylim(0.1,9.5)


sub5=plt.subplot(4, 4, 5)##############################################################
#大值攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum2_DGD_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum2_IOS_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum2_TM_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum2_SCC_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],sum2_BREDA_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

#plt.xlabel('number of iterations',font)
plt.ylabel('dual optimality',font)
#plt.title('Large value attacks',font)
#plt.ylim(2.4,7.9)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub5.set_xticks(x_ticks)'''

plt.yticks([2,4,6,8,10,12,14], [r'$2^{2}$', r'$2^{4}$',r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$', r'$2^{14}$'])

sub6=plt.subplot(4, 4, 6)##############################################################
#小值攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum2_DGD_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum2_IOS_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum2_TM_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum2_SCC_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],sum2_BREDA_small_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

#plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Small value attacks',font)
#plt.ylim(2.4,7.9)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub6.set_xticks(x_ticks)'''

#plt.yticks([6, 8, 10, 12], [r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$'])

sub7=plt.subplot(4, 4, 7)##############################################################
#大值高斯攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum2_DGD_Gaussian_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum2_IOS_Gaussian_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum2_TM_Gaussian_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum2_SCC_Gaussian_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

#plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Trimmed large value Gaussian attacks',font)
#plt.ylim(2.4,7.9)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub7.set_xticks(x_ticks)'''

#plt.yticks([6, 8, 10, 12], [r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$'])

sub8=plt.subplot(4, 4, 8)##############################################################
#小值高斯攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],sum2_DGD_Gaussian_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],sum2_IOS_Gaussian_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],sum2_TM_Gaussian_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],sum2_SCC_Gaussian_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

#plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Trimmed small value Gaussian attacks',font)
#plt.ylim(2.4,7.9)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub8.set_xticks(x_ticks)'''

#plt.yticks([6, 8, 10, 12], [r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$'])

sub9=plt.subplot(4, 4, 9)##############################################################
#大值攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_DGD_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_IOS_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_TM_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_SCC_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_BREDA_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

#plt.xlabel('Number of iterations',font)
plt.ylabel('cost optimality',font)
#plt.title('large-value',font)  
#plt.ylim(3,14)

plt.yticks([2, 4, 6, 8, 10, 12], [r'$2^{2}$',r'$2^{4}$', r'$2^{6}$', r'$2^{8}$', r'$2^{10}$', r'$2^{12}$'])

sub10=plt.subplot(4, 4, 10)##############################################################
#小值攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_DGD_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_IOS_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_TM_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_SCC_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_BREDA_small_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)
#plt.ylim(3,14)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
#plt.title('small-value',font)
#plt.ylim(0,12000)


sub11=plt.subplot(4, 4, 11)##############################################################
#大值高斯攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_DGD_Gaussian_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_IOS_Gaussian_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_TM_Gaussian_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_SCC_Gaussian_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)
#plt.ylim(3,14)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
#plt.title('large-value Gaussian',font, x=0.57,y=1)

sub12=plt.subplot(4, 4, 12)##############################################################
#小值高斯攻击 评价指标：所有诚实用户资源量和无攻击情况下最优资源量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_DGD_Gaussian_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_IOS_Gaussian_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_TM_Gaussian_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],cost_gap_SCC_Gaussian_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)
#plt.ylim(3,14)

#plt.xlabel('Number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\theta_{i}^{k}-\theta_{i}^{*}||)$ ',font)
#plt.title('small-value Gaussian ',font, x=0.57,y=1)
#plt.ylim(0,20000)
#plt.ylim(0,12000)

sub13=plt.subplot(4, 4, 13)##############################################################
#大值攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_DGD_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_IOS_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_TM_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_SCC_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_BREDA_large_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

plt.xlabel('number of iterations',font)
plt.ylabel('constraint violation',font)
#plt.title('Large value attacks',font)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub5.set_xticks(x_ticks)'''

plt.yticks([-6, -4, -2, 0, 2, 4, 6], [r'$2^{-6}$', r'$2^{-4}$', r'$2^{-2}$', r'$2^{0}$', r'$2^{2}$', r'$2^{4}$', r'$2^{6}$'])

sub14=plt.subplot(4, 4, 14)##############################################################
#小值攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_DGD_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_IOS_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_TM_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_SCC_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
E,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_BREDA_small_log2[slice(0,40000,2000)],marker = '>',markersize=10,color = 'deepskyblue',linewidth = '3',label='BREDA')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,E,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Small value attacks',font)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub6.set_xticks(x_ticks)'''

sub15=plt.subplot(4, 4, 15)##############################################################
#大值高斯攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_DGD_Gaussian_large_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_IOS_Gaussian_large_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_TM_Gaussian_large_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_SCC_Gaussian_large_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

plt.xlabel('number of iterations',font)
#plt.ylabel(r' $\log(\sum_{i\in \mathcal{H}}||\lambda_{i}^{k}-\lambda^{*}||)$ ',font)
#plt.title('Trimmed large value Gaussian attacks',font)

'''x_ticks = np.arange(0, 40000, 20000)
x_ticks = np.delete(x_ticks, -1) # 删除最后一个刻度
sub7.set_xticks(x_ticks)'''

sub16=plt.subplot(4, 4, 16)##############################################################
#小值高斯攻击 评价指标：所有诚实用户对偶变量和无攻击情况下最优对偶变量的gap
iteration=[]
iteration.append(0)
for i in range(0,39999):
    iteration.append(i)

#在同一幅图片上画4条折线
A,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_DGD_Gaussian_small_log2[slice(0,40000,2000)],marker = '*',markersize=10,color = 'dimgrey',linewidth = '3',label='attack-free')
B,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_IOS_Gaussian_small_log2[slice(0,40000,2000)],marker = 'D',markersize=10,color = 'mediumseagreen',linewidth = '3',label='proposed+IOS')
C,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_TM_Gaussian_small_log2[slice(0,40000,2000)],marker = 's',markersize=10,color = 'palevioletred',linewidth = '3',label='proposed+CTM')
D,=plt.plot(iteration[slice(0,39999,2000)],average_resource_gap_SCC_Gaussian_small_log2[slice(0,40000,2000)],marker = 'o',markersize=10,color = 'orange',linewidth = '3',label='proposed+SCC')
#设置图例并且设置图例的字体及大小
font = {
'size'   : 62,
'family': 'Times New Roman'
}
#legend = plt.legend(handles=[A,B,C,D],prop=font,loc='center right',bbox_to_anchor=(1, 0.7))
 
#设置坐标刻度值的大小以及刻度值的字体
plt.tick_params(labelsize=35)

plt.xlabel('number of iterations',font)

plt.legend(handles=[A, C, B, D, E],prop={'size':45},loc="upper center", bbox_to_anchor=[-1.06, -0.2],
           ncol=18, shadow=True, fancybox=True)
sub1.set_xticklabels([])
sub2.set_xticklabels([])
sub3.set_xticklabels([])
sub4.set_xticklabels([])
sub5.set_xticklabels([])
sub6.set_xticklabels([])
sub7.set_xticklabels([])
sub8.set_xticklabels([])
sub9.set_xticklabels([])
sub10.set_xticklabels([])
sub11.set_xticklabels([])
sub12.set_xticklabels([])

sub2.set_yticklabels([])
sub3.set_yticklabels([])
sub4.set_yticklabels([])

sub6.set_yticklabels([])
sub7.set_yticklabels([])
sub8.set_yticklabels([])

sub10.set_yticklabels([])
sub11.set_yticklabels([])
sub12.set_yticklabels([])

sub14.set_yticklabels([])
sub15.set_yticklabels([])
sub16.set_yticklabels([])


plt.subplots_adjust(wspace=0.03,hspace=0.05) 
plt.gcf().set_size_inches((38, 35))

plt.savefig('./figures/figure1_2_primal_dual_cost_constraint_oracle_log2_four_attacks.pdf',format='pdf', bbox_inches='tight')
plt.savefig('./figures/figure1_2_primal_dual_cost_constraint_oracle_log2_four_attacks.png',format='png', bbox_inches='tight')
# Out:
# meta NOT subset; don't know how to subset; dropped

# %% [markdown]
# # 计算一致性误差

# %%
#DGD 无攻击
consensus_error_DGD=[]
average_dual_DGD=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_oracle[i][k]
    average_dual_DGD.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_oracle[i][k]-average_dual_DGD[k])*abs(dual_variable_oracle[i][k]-average_dual_DGD[k])
    consensus_error_DGD.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_DGD[59899+i]

# %%
sum/100
# Out:
# 3.0373038117181485e-25

# %%
consensus_error_DGD[59998]
# Out:
# 3.0373038117181485e-25

# %%
#DGD 小值攻击
consensus_error_DGD_min=[]
average_dual_DGD_min=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_min_attack[i][k]
    average_dual_DGD_min.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack[i][k]-average_dual_DGD_min[k])*abs(dual_variable_min_attack[i][k]-average_dual_DGD_min[k])
    consensus_error_DGD_min.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_DGD_min[59899+i]

# %%
sum/100
# Out:
# 0.5183227266738782

# %%
consensus_error_DGD_min[59998]
# Out:
# 0.5181515486084932

# %%
#DGD 大值攻击
consensus_error_DGD_max=[]
average_dual_DGD_max=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_max_attack[i][k]
    average_dual_DGD_max.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack[i][k]-average_dual_DGD_max[k])*abs(dual_variable_max_attack[i][k]-average_dual_DGD_max[k])
    consensus_error_DGD_max.append(sum/94)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_DGD_max[59899+i]

# %%
sum/100
# Out:
# 0.004990624904899687

# %%
consensus_error_DGD_max[59998]
# Out:
# 0.004988989186877732

# %%
#DGD 高斯攻击——大值
consensus_error_DGD_Gaussian_large=[]
average_dual_DGD_Gaussian_large=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_Gaussian_attack_large[i][k]
    average_dual_DGD_Gaussian_large.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_large[i][k]-average_dual_DGD_Gaussian_large[k])*abs(dual_variable_Gaussian_attack_large[i][k]-average_dual_DGD_Gaussian_large[k])
    consensus_error_DGD_Gaussian_large.append(sum/94)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_DGD_Gaussian_large[59899+i]

# %%
sum/100
# Out:
# 0.08735905034880004

# %%
consensus_error_DGD_Gaussian_large[59998]
# Out:
# 0.06518581893383359

# %%
#DGD 高斯攻击——小值
consensus_error_DGD_Gaussian_small=[]
average_dual_DGD_Gaussian_small=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_Gaussian_attack_small[i][k]
    average_dual_DGD_Gaussian_small.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_small[i][k]-average_dual_DGD_Gaussian_small[k])*abs(dual_variable_Gaussian_attack_small[i][k]-average_dual_DGD_Gaussian_small[k])
    consensus_error_DGD_Gaussian_small.append(sum/94)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_DGD_Gaussian_small[59899+i]

# %%
sum/100
# Out:
# 4.789259155715733

# %%
consensus_error_DGD_Gaussian_small[59998]
# Out:
# 5.052168132236095

# %%
#IOS 小值攻击
consensus_error_IOS_min=[]
average_dual_IOS_min=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_min_attack_IOS[i][k]
    average_dual_IOS_min.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack_IOS[i][k]-average_dual_IOS_min[k])*abs(dual_variable_min_attack_IOS[i][k]-average_dual_IOS_min[k])
    consensus_error_IOS_min.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_IOS_min[59899+i]

# %%
sum/100
# Out:
# 0.010853829660628114

# %%
consensus_error_IOS_min[59998]
# Out:
# 0.010852038950682052

# %%
#IOS 大值攻击
consensus_error_IOS_max=[]
average_dual_IOS_max=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_max_attack_IOS[i][k]
    average_dual_IOS_max.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack_IOS[i][k]-average_dual_IOS_max[k])*abs(dual_variable_max_attack_IOS[i][k]-average_dual_IOS_max[k])
    consensus_error_IOS_max.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_IOS_max[59899+i]

# %%
sum/100
# Out:
# 0.010853829660628114

# %%
consensus_error_IOS_max[59998]
# Out:
# 0.010852038950682052

# %%
#IOS 高斯攻击——大值
consensus_error_IOS_Gaussian_large=[]
average_dual_IOS_Gaussian_large=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_Gaussian_attack_large_IOS[i][k]
    average_dual_IOS_Gaussian_large.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_large_IOS[i][k]-average_dual_IOS_Gaussian_large[k])*abs(dual_variable_Gaussian_attack_large_IOS[i][k]-average_dual_IOS_Gaussian_large[k])
    consensus_error_IOS_Gaussian_large.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_IOS_Gaussian_large[59899+i]

# %%
sum/100
# Out:
# 0.010853829660628114

# %%
consensus_error_IOS_Gaussian_large[59998]
# Out:
# 0.010852038950682052

# %%
#IOS 高斯攻击——小值
consensus_error_IOS_Gaussian_small=[]
average_dual_IOS_Gaussian_small=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_Gaussian_attack_small_IOS[i][k]
    average_dual_IOS_Gaussian_small.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_small_IOS[i][k]-average_dual_IOS_Gaussian_small[k])*abs(dual_variable_Gaussian_attack_small_IOS[i][k]-average_dual_IOS_Gaussian_small[k])
    consensus_error_IOS_Gaussian_small.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_IOS_Gaussian_small[59899+i]

# %%
sum/100
# Out:
# 0.010853829660628114

# %%
consensus_error_IOS_Gaussian_small[59998]
# Out:
# 0.010852038950682052

# %%
#CTM 小值攻击
consensus_error_TM_min=[]
average_dual_TM_min=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_min_attack_TM[i][k]
    average_dual_TM_min.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack_TM[i][k]-average_dual_TM_min[k])*abs(dual_variable_min_attack_TM[i][k]-average_dual_TM_min[k])
    consensus_error_TM_min.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_TM_min[59899+i]

# %%
sum/100
# Out:
# 0.010716583941303781

# %%
consensus_error_TM_min[58889]
# Out:
# 0.010754854911477318

# %%
#CTM 大值攻击
consensus_error_TM_max=[]
average_dual_TM_max=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_max_attack_TM[i][k]
    average_dual_TM_max.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack_TM[i][k]-average_dual_TM_max[k])*abs(dual_variable_max_attack_TM[i][k]-average_dual_TM_max[k])
    consensus_error_TM_max.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_TM_max[59899+i]

# %%
sum/100
# Out:
# 0.011969724517228345

# %%
consensus_error_TM_max[58889]
# Out:
# 0.01201246536251126

# %%
#CTM 高斯攻击——大值
consensus_error_TM_Gaussian_large=[]
average_dual_TM_Gaussian_large=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_Gaussian_attack_large_TM[i][k]
    average_dual_TM_Gaussian_large.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_large_TM[i][k]-average_dual_TM_Gaussian_large[k])*abs(dual_variable_Gaussian_attack_large_TM[i][k]-average_dual_TM_Gaussian_large[k])
    consensus_error_TM_Gaussian_large.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_TM_Gaussian_large[59899+i]

# %%
sum/100
# Out:
# 0.011969724517228345

# %%
consensus_error_TM_Gaussian_large[58889]
# Out:
# 0.01201246536251126

# %%
#CTM 高斯攻击——小值
consensus_error_TM_Gaussian_small=[]
average_dual_TM_Gaussian_small=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_Gaussian_attack_small_TM[i][k]
    average_dual_TM_Gaussian_small.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_small_TM[i][k]-average_dual_TM_Gaussian_small[k])*abs(dual_variable_Gaussian_attack_small_TM[i][k]-average_dual_TM_Gaussian_small[k])
    consensus_error_TM_Gaussian_small.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_TM_Gaussian_small[59899+i]

# %%
sum/100
# Out:
# 0.010716583748335638

# %%
consensus_error_TM_Gaussian_small[58889]
# Out:
# 0.01075485519019883

# %%
#SCC 小值攻击
consensus_error_SCC_min=[]
average_dual_SCC_min=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_min_attack_SCC[i][k]
    average_dual_SCC_min.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack_SCC[i][k]-average_dual_SCC_min[k])*abs(dual_variable_min_attack_SCC[i][k]-average_dual_SCC_min[k])
    consensus_error_SCC_min.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_SCC_min[59899+i]

# %%
sum/100
# Out:
# 0.03157547573984076

# %%
consensus_error_SCC_min[59998]
# Out:
# 0.03157026987422923

# %%
#SCC 大值攻击
consensus_error_SCC_max=[]
average_dual_SCC_max=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_max_attack_SCC[i][k]
    average_dual_SCC_max.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack_SCC[i][k]-average_dual_SCC_max[k])*abs(dual_variable_max_attack_SCC[i][k]-average_dual_SCC_max[k])
    consensus_error_SCC_max.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_SCC_max[59899+i]

# %%
sum/100
# Out:
# 0.033634085818238166

# %%
consensus_error_SCC_max[59998]
# Out:
# 0.03362854062658037

# %%
#SCC 高斯攻击——大值
consensus_error_SCC_Gaussian_large=[]
average_dual_SCC_Gaussian_large=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_Gaussian_attack_large_SCC[i][k]
    average_dual_SCC_Gaussian_large.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_large_SCC[i][k]-average_dual_SCC_Gaussian_large[k])*abs(dual_variable_Gaussian_attack_large_SCC[i][k]-average_dual_SCC_Gaussian_large[k])
    consensus_error_SCC_Gaussian_large.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_SCC_Gaussian_large[59899+i]

# %%
sum/100
# Out:
# 0.033634085818238166

# %%
consensus_error_SCC_Gaussian_large[59998]
# Out:
# 0.03362854062658037

# %%
#SCC 高斯攻击——小值
consensus_error_SCC_Gaussian_small=[]
average_dual_SCC_Gaussian_small=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_Gaussian_attack_small_SCC[i][k]
    average_dual_SCC_Gaussian_small.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_Gaussian_attack_small_SCC[i][k]-average_dual_SCC_Gaussian_small[k])*abs(dual_variable_Gaussian_attack_small_SCC[i][k]-average_dual_SCC_Gaussian_small[k])
    consensus_error_SCC_Gaussian_small.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_SCC_Gaussian_small[59899+i]

# %%
sum/100
# Out:
# 0.03157547454767648

# %%
consensus_error_SCC_Gaussian_small[59998]
# Out:
# 0.03157026952313136

# %%
#BREDA 小值攻击
consensus_error_BREDA_min=[]
average_dual_BREDA_min=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_min_attack_BREDA[i][k]
    average_dual_BREDA_min.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_min_attack_BREDA[i][k]-average_dual_BREDA_min[k])*abs(dual_variable_min_attack_BREDA[i][k]-average_dual_BREDA_min[k])
    consensus_error_BREDA_min.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_BREDA_min[59899+i]

# %%
sum/100
# Out:
# 121.08725773975615

# %%
consensus_error_BREDA_min[59998]
# Out:
# 121.0872577397559

# %%
#BREDA 大值攻击
consensus_error_BREDA_max=[]
average_dual_BREDA_max=[]
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+dual_variable_max_attack_BREDA[i][k]
    average_dual_BREDA_max.append(sum/94)
for k in range(0,59999):
    sum=0
    for i in range(0,94):
        sum=sum+abs(dual_variable_max_attack_BREDA[i][k]-average_dual_BREDA_max[k])*abs(dual_variable_max_attack_BREDA[i][k]-average_dual_BREDA_max[k])
    consensus_error_BREDA_max.append(sum)

# %%
#以最后100次迭代的一致性误差平均作为评价指标
sum=0
for i in range(0,100):
    sum=sum+consensus_error_BREDA_max[59899+i]

# %%
sum/100
# Out:
# 105.6972929212765

# %%
consensus_error_BREDA_max[59998]
# Out:
# 105.69729292127651
